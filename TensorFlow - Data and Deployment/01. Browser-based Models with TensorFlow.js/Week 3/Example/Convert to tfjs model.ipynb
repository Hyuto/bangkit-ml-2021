# %% [markdown]
# # Convert Keras model to Tensorflowjs model
#
# Further reading : [Importing a Keras model into TensorFlow.js](https://www.tensorflow.org/js/tutorials/conversion/import_keras)
#
# **Step 1**
#
# Install Tensorflowjs convertor

# %%
# !pip install -q --no-deps tensorflowjs
# !pip install -q tensorflow_hub

# %% [markdown]
# **Step 2**
#
# Build and save a model

# %%
import numpy as np
import tensorflow as tf

print('\u2022 Using TensorFlow Version:', tf.__version__)
# Out:
# • Using TensorFlow Version: 2.3.1

# %%
# Build model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=[1])  
])
model.compile(optimizer='rmsprop', loss='mean_squared_error')

xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)
# Out:
#  0s 999us/step - loss: 1.9034
# Epoch 252/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8988
# Epoch 253/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8942
# Epoch 254/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8896
# Epoch 255/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8851
# Epoch 256/500
# 1/1 [==============================] - 0s 999us/step - loss: 1.8805
# Epoch 257/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8759
# Epoch 258/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8713
# Epoch 259/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8668
# Epoch 260/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8622
# Epoch 261/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8576
# Epoch 262/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8531
# Epoch 263/500
# ...

# %%
# Save model
if not os.path.isdir('model'):
    os.mkdir('model')
model.save('model/model.h5')

# %% [markdown]
# **Step 3**
#
# Convert using `tensorflowjs_converter` or via Python API
#
# 1. `tensorflowjs_converter`
#     ```bash
#     tensorflowjs_converter --input_format keras \
#                            path/to/my_model.h5 \
#                            path/to/tfjs_target_dir
#     ```
# 2. Python API<br>
#     ```python
#     import tensorflowjs as tfjs
#     tfjs.converters.save_keras_model(model, tfjs_target_dir)
#     ```

# %%
# converter
# !tensorflowjs_converter --input_format=keras \
    model/model.h5 \
    model/my_model

# API
# tfjs.converters.save_keras_model(model, 'model')
# Out:
# 2021-04-22 15:33:32.656487: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cudart64_101.dll
