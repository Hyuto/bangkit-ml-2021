# %%
# !pip install tf-nightly-2.0-preview
# Out:
# ERROR: Could not find a version that satisfies the requirement tf-nightly-2.0-preview (from versions: none)
# ERROR: No matching distribution found for tf-nightly-2.0-preview

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.4.1

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(False)

def trend(time, slope=0):
    return slope * time

def seasonal_pattern(season_time):
    """Just an arbitrary pattern, you can change it if you wish"""
    return np.where(season_time < 0.1,
                    np.cos(season_time * 6 * np.pi),
                    2 / np.exp(9 * season_time))

def seasonality(time, period, amplitude=1, phase=0):
    """Repeats the same pattern at each period"""
    season_time = ((time + phase) % period) / period
    return amplitude * seasonal_pattern(season_time)

def noise(time, noise_level=1, seed=None):
    rnd = np.random.RandomState(seed)
    return rnd.randn(len(time)) * noise_level

time = np.arange(10 * 365 + 1, dtype="float32")
baseline = 10
series = trend(time, 0.1)
amplitude = 40
slope = 0.005
noise_level = 3

# Create the series
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)
# Update with noise
series += noise(time, noise_level, seed=51)

split_time = 3000
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

window_size = 20
batch_size = 32
shuffle_buffer_size = 1000

plot_series(time, series)

# %% [markdown]
# Desired output -- a chart that looks like this:
#
# ![Chart showing upward trend and seasonailty](http://www.laurencemoroney.com/wp-content/uploads/2019/07/plot1.png)

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
  dataset = tf.data.Dataset.from_tensor_slices(series)
  dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
  dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
  dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1]))
  dataset = dataset.batch(batch_size).prefetch(1)
  return dataset

# %%
dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)


model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape = [window_size], activation="relu"),
    tf.keras.layers.Dense(16, activation="relu"), 
    tf.keras.layers.Dense(1)
])

model.compile(loss='mae', optimizer=tf.keras.optimizers.RMSprop(6e-4))
model.fit(dataset, epochs=100)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 1s 4ms/step - loss: 5.4586
# Epoch 2/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.6598
# Epoch 3/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.4295
# Epoch 4/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.3606
# Epoch 5/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.2626
# Epoch 6/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.1812
# Epoch 7/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.1594
# Epoch 8/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.1289
# Epoch 9/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.1649
# Epoch 10/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.0403
# Epoch 11/100
# 94/94 [==============================] - 1s 5ms/step - loss: 3.0035
# Epoch 12/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.0257
# Epoch 13/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.1136
# Epoch 14/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.0391
# Epoch 15/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.0500
# Epoch 16/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.9614
# Epoch 17/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.0658
# Epoch 18/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.9840
# Epoch 19/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.9911
# Epoch 20/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.0158
# Epoch 21/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.0006
# Epoch 22/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.9483
# Epoch 23/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.9137
# Epoch 24/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.9882
# Epoch 25/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8929
# Epoch 26/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.9519
# Epoch 27/100
# 94/94 [==============================] - 1s 5ms/step - loss: 3.0109
# Epoch 28/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.9572
# Epoch 29/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8945
# Epoch 30/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8169
# Epoch 31/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.0140
# Epoch 32/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8281
# Epoch 33/100
# 94/94 [==============================] - 0s 4ms/step - loss: 3.0077
# Epoch 34/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8502
# Epoch 35/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8012
# Epoch 36/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8307
# Epoch 37/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.9688
# Epoch 38/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8808
# Epoch 39/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8581
# Epoch 40/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8745
# Epoch 41/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8589
# Epoch 42/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8796
# Epoch 43/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8092
# Epoch 44/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8778
# Epoch 45/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8037
# Epoch 46/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8313
# Epoch 47/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8780
# Epoch 48/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8289
# Epoch 49/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8164
# Epoch 50/100
# 94/94 [==============================] - 1s 5ms/step - loss: 2.7685
# Epoch 51/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7336
# Epoch 52/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.9253
# Epoch 53/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7923
# Epoch 54/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8183
# Epoch 55/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7761
# Epoch 56/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7851
# Epoch 57/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8527
# Epoch 58/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8319
# Epoch 59/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8176
# Epoch 60/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8182
# Epoch 61/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8166
# Epoch 62/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8798
# Epoch 63/100
# 94/94 [==============================] - 1s 4ms/step - loss: 2.7664
# Epoch 64/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7364
# Epoch 65/100
# 94/94 [==============================] - 1s 4ms/step - loss: 2.8290
# Epoch 66/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7946
# Epoch 67/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.9164
# Epoch 68/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7416
# Epoch 69/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8165
# Epoch 70/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7503
# Epoch 71/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7528
# Epoch 72/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7917
# Epoch 73/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8013
# Epoch 74/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8037
# Epoch 75/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7362
# Epoch 76/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8128
# Epoch 77/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7508
# Epoch 78/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7614
# Epoch 79/100
# 94/94 [==============================] - 1s 5ms/step - loss: 2.8295
# Epoch 80/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8027
# Epoch 81/100
# 94/94 [==============================] - 1s 5ms/step - loss: 2.7160
# Epoch 82/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7413
# Epoch 83/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7226
# Epoch 84/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8147
# Epoch 85/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7362
# Epoch 86/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7885
# Epoch 87/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8099
# Epoch 88/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.6879
# Epoch 89/100
# 94/94 [==============================] - 1s 4ms/step - loss: 2.7355
# Epoch 90/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7232
# Epoch 91/100
# 94/94 [==============================] - 1s 4ms/step - loss: 2.7758
# Epoch 92/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.7289
# Epoch 93/100
# 94/94 [==============================] - 1s 5ms/step - loss: 2.7785
# Epoch 94/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.6710
# Epoch 95/100
# 94/94 [==============================] - 1s 5ms/step - loss: 2.7181
# Epoch 96/100
# 94/94 [==============================] - 1s 5ms/step - loss: 2.7114
# Epoch 97/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.8098
# Epoch 98/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.6575
# Epoch 99/100
# 94/94 [==============================] - 0s 4ms/step - loss: 2.6947
# Epoch 100/100
# 94/94 [==============================] - 1s 4ms/step - loss: 2.7737

# %%
forecast = []
for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]


plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# EXPECTED OUTPUT
# A Value less than 3
# Out:
# 2.8702247
