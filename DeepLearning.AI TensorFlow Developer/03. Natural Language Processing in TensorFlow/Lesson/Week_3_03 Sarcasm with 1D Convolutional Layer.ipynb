# %%
import numpy as np

import json
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json \
    -O /tmp/sarcasm.json

vocab_size = 1000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000


with open("/tmp/sarcasm.json", 'r') as f:
    datastore = json.load(f)


sentences = []
labels = []
urls = []
for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 50

training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)

history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=1)
# Out:
# --2021-04-08 18:05:35--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.71.128, 64.233.184.128, 173.194.76.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.71.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘/tmp/sarcasm.json’
#
# /tmp/sarcasm.json   100%[===================>]   5.38M  --.-KB/s    in 0.05s
#
# 2021-04-08 18:05:36 (106 MB/s) - ‘/tmp/sarcasm.json’ saved [5643545/5643545]
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           16000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 116, 128)          10368
# _________________________________________________________________
# global_max_pooling1d (Global (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 24)                3096
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 29,489
# Trainable params: 29,489
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 625/625 [==============================] - 34s 7ms/step - loss: 0.5697 - accuracy: 0.6741 - val_loss: 0.4069 - val_accuracy: 0.8179
# Epoch 2/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3575 - accuracy: 0.8383 - val_loss: 0.3935 - val_accuracy: 0.8246
# Epoch 3/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3163 - accuracy: 0.8628 - val_loss: 0.3915 - val_accuracy: 0.8238
# Epoch 4/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.2819 - accuracy: 0.8796 - val_loss: 0.4070 - val_accuracy: 0.8207
# Epoch 5/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.2463 - accuracy: 0.8965 - val_loss: 0.4322 - val_accuracy: 0.8174
# Epoch 6/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.2217 - accuracy: 0.9097 - val_loss: 0.4454 - val_accuracy: 0.8165
# Epoch 7/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.1859 - accuracy: 0.9270 - val_loss: 0.4887 - val_accuracy: 0.8088
# Epoch 8/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.1555 - accuracy: 0.9435 - val_loss: 0.5561 - val_accuracy: 0.8056
# Epoch 9/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.1342 - accuracy: 0.9498 - val_loss: 0.6529 - val_accuracy: 0.8018
# Epoch 10/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.1098 - accuracy: 0.9615 - val_loss: 0.7000 - val_accuracy: 0.8035
# Epoch 11/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0894 - accuracy: 0.9687 - val_loss: 0.7642 - val_accuracy: 0.7898
# Epoch 12/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0733 - accuracy: 0.9764 - val_loss: 0.8696 - val_accuracy: 0.7964
# Epoch 13/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0620 - accuracy: 0.9785 - val_loss: 0.9547 - val_accuracy: 0.7946
# Epoch 14/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0561 - accuracy: 0.9809 - val_loss: 1.0303 - val_accuracy: 0.7909
# Epoch 15/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0441 - accuracy: 0.9860 - val_loss: 1.1879 - val_accuracy: 0.7867
# Epoch 16/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0409 - accuracy: 0.9849 - val_loss: 1.2764 - val_accuracy: 0.7861
# Epoch 17/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0388 - accuracy: 0.9865 - val_loss: 1.3118 - val_accuracy: 0.7874
# Epoch 18/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0354 - accuracy: 0.9863 - val_loss: 1.4742 - val_accuracy: 0.7869
# Epoch 19/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0375 - accuracy: 0.9861 - val_loss: 1.4512 - val_accuracy: 0.7866
# Epoch 20/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0342 - accuracy: 0.9871 - val_loss: 1.5825 - val_accuracy: 0.7828
# Epoch 21/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0296 - accuracy: 0.9882 - val_loss: 1.6594 - val_accuracy: 0.7882
# Epoch 22/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0268 - accuracy: 0.9895 - val_loss: 1.7336 - val_accuracy: 0.7755
# Epoch 23/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0300 - accuracy: 0.9883 - val_loss: 1.8042 - val_accuracy: 0.7915
# Epoch 24/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0326 - accuracy: 0.9864 - val_loss: 1.8024 - val_accuracy: 0.7798
# Epoch 25/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0284 - accuracy: 0.9890 - val_loss: 1.8459 - val_accuracy: 0.7877
# Epoch 26/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0225 - accuracy: 0.9903 - val_loss: 1.8354 - val_accuracy: 0.7876
# Epoch 27/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0207 - accuracy: 0.9922 - val_loss: 1.9101 - val_accuracy: 0.7900
# Epoch 28/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0293 - accuracy: 0.9890 - val_loss: 1.9184 - val_accuracy: 0.7888
# Epoch 29/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0263 - accuracy: 0.9886 - val_loss: 1.8813 - val_accuracy: 0.7818
# Epoch 30/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0231 - accuracy: 0.9901 - val_loss: 2.0175 - val_accuracy: 0.7906
# Epoch 31/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0228 - accuracy: 0.9907 - val_loss: 2.1084 - val_accuracy: 0.7861
# Epoch 32/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0222 - accuracy: 0.9912 - val_loss: 2.0966 - val_accuracy: 0.7810
# Epoch 33/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0233 - accuracy: 0.9896 - val_loss: 1.9963 - val_accuracy: 0.7839
# Epoch 34/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0185 - accuracy: 0.9925 - val_loss: 2.1390 - val_accuracy: 0.7813
# Epoch 35/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0199 - accuracy: 0.9908 - val_loss: 2.3264 - val_accuracy: 0.7877
# Epoch 36/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0210 - accuracy: 0.9915 - val_loss: 2.0678 - val_accuracy: 0.7828
# Epoch 37/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0195 - accuracy: 0.9915 - val_loss: 2.2918 - val_accuracy: 0.7790
# Epoch 38/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0219 - accuracy: 0.9908 - val_loss: 2.2286 - val_accuracy: 0.7849
# Epoch 39/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0194 - accuracy: 0.9917 - val_loss: 2.2891 - val_accuracy: 0.7795
# Epoch 40/50
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0170 - accuracy: 0.9924 - val_loss: 2.3824 - val_accuracy: 0.7818
# Epoch 41/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0183 - accuracy: 0.9915 - val_loss: 2.2732 - val_accuracy: 0.7806
# Epoch 42/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0204 - accuracy: 0.9912 - val_loss: 2.3221 - val_accuracy: 0.7852
# Epoch 43/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0194 - accuracy: 0.9917 - val_loss: 2.5166 - val_accuracy: 0.7816
# Epoch 44/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0205 - accuracy: 0.9917 - val_loss: 2.4292 - val_accuracy: 0.7819
# Epoch 45/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0175 - accuracy: 0.9927 - val_loss: 2.4396 - val_accuracy: 0.7819
# Epoch 46/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0191 - accuracy: 0.9911 - val_loss: 2.6614 - val_accuracy: 0.7849
# Epoch 47/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0191 - accuracy: 0.9918 - val_loss: 2.5417 - val_accuracy: 0.7822
# Epoch 48/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0194 - accuracy: 0.9919 - val_loss: 2.4999 - val_accuracy: 0.7851
# Epoch 49/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0194 - accuracy: 0.9906 - val_loss: 2.4727 - val_accuracy: 0.7840
# Epoch 50/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0177 - accuracy: 0.9911 - val_loss: 2.7044 - val_accuracy: 0.7822

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
model.save("test.h5")
